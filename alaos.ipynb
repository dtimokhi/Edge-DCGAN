# %%
import numpy as np
import cv2 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('tiny-imagenet-200/train/n01443537/images/n01443537_0.JPEG')

# %%
edges = cv2.Canny(img,64,64)

# %%
plt.imshow(edges)

# %%
edges_2 = np.where(edges == 255, 1, edges)

# %%
plt.imshow(edges_2)

# %%
edges_2.shape
# Out:
# (64, 64)

# %%
lab_image = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
l_channel,a_channel,b_channel = cv2.split(lab_image)

# %%
plt.imshow(l_channel)
